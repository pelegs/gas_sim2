# %%
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.set_cmap('rainbow')

# %%
vels = np.load('vels.npy')

# %%
bins = np.linspace(0, 20, 50)
h, _ = np.histogram(vels, bins)

# %%
plt.bar(bins[:-1], h)
# Out:
# <Container object of 49 artists>

# %%
Ek = np.load('kinteic_energy.npy')

# %%
plt.plot(Ek)
